# %% [markdown]
# # Ablation Results
# Load the ablation summary after running `python -m evaluation.ablation`.

# %%
import json
from pathlib import Path
summary = json.loads(Path('../experiments/results/ablation_summary.json').read_text(encoding='utf-8'))
summary
