# %% [markdown]
# # KB Statistics
# Inspect the generated knowledge-base manifest and source-type distribution.

# %%
import json
from pathlib import Path
manifest = json.loads(Path('../data/kb/manifest.json').read_text(encoding='utf-8'))
manifest
