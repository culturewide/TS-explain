# %% [markdown]
# # Feature Analysis
# Create a synthetic window and render its TS-Fact Card.

# %%
import numpy as np
from feature_extraction.extractor import TSFeatureExtractor
t = np.arange(96)
x = np.stack([0.02*t + np.sin(2*np.pi*t/24), np.cos(2*np.pi*t/12)], axis=1)
x[40:48, 1] += 3
card = TSFeatureExtractor().extract(x, window_id='demo')
print(card.narrative)
